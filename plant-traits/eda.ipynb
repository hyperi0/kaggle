# %%
from IPython.display import Image

import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('data/train.csv')

# %%
train_data.head()
# Out:
#           id  WORLDCLIM_BIO1_annual_mean_temperature  \
# 0  192027691                               12.235703
# 1  195542235                               17.270555
# 2  196639184                               14.254504
# 3  195728812                               18.680834
# 4  195251545                                0.673204
#
#    WORLDCLIM_BIO12_annual_precipitation  \
# 0                            374.466675
# 1                             90.239998
# 2                            902.071411
# 3                           1473.933350
# 4                            530.088867
#
#    WORLDCLIM_BIO13.BIO14_delta_precipitation_of_wettest_and_dryest_month  \
# 0                                          62.524445
# 1                                          10.351111
# 2                                          49.642857
# 3                                         163.100006
# 4                                          50.857777
#
#    WORLDCLIM_BIO15_precipitation_seasonality  \
# ...

# %%
train_data.describe()
# Out:
#                  id  WORLDCLIM_BIO1_annual_mean_temperature  \
# count  5.548900e+04                            55489.000000
# mean   1.714553e+08                               14.577142
# std    4.087868e+07                                7.584290
# min    2.637500e+04                              -13.731130
# 25%    1.658614e+08                                9.247916
# 50%    1.915103e+08                               15.536692
# 75%    1.951001e+08                               20.238457
# max    1.967668e+08                               30.294445
#
#        WORLDCLIM_BIO12_annual_precipitation  \
# count                          55489.000000
# mean                            1058.710939
# std                              768.992166
# min                                0.000000
# 25%                              528.315552
# 50%                              853.776184
# 75%                             1352.000000
# max                             8392.463867
#
# ...

# %%
output_vars = [col for col in train_data.columns if col.startswith('X') and col.endswith('mean')]

# %%
output_vars
# Out:
# ['X4_mean', 'X11_mean', 'X18_mean', 'X26_mean', 'X50_mean', 'X3112_mean']
